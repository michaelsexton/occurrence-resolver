# %%
import db

# %%
db.get_commodities()
# Out:
# [{'COMMODID': 'Ag', 'COMMODNAME': 'Silver'},
#  {'COMMODID': 'Pb', 'COMMODNAME': 'Lead'},
#  {'COMMODID': 'Zn', 'COMMODNAME': 'Zinc'},
#  {'COMMODID': 'Cu', 'COMMODNAME': 'Copper'},
#  {'COMMODID': 'Zr', 'COMMODNAME': 'Zirconium'},
#  {'COMMODID': 'Al', 'COMMODNAME': 'Aluminium'},
#  {'COMMODID': 'Bx', 'COMMODNAME': 'Bauxite'},
#  {'COMMODID': 'Gp', 'COMMODNAME': 'Gypsum'},
#  {'COMMODID': 'Sb', 'COMMODNAME': 'Antimony'},
#  {'COMMODID': 'As', 'COMMODNAME': 'Arsenic'},
#  {'COMMODID': 'Ba', 'COMMODNAME': 'Barium'},
#  {'COMMODID': 'Be', 'COMMODNAME': 'Beryllium'},
#  {'COMMODID': 'Cd', 'COMMODNAME': 'Cadmium'},
#  {'COMMODID': 'Cs', 'COMMODNAME': 'Cesium'},
#  {'COMMODID': 'Kln', 'COMMODNAME': 'Kaolin'},
#  {'COMMODID': 'Cor', 'COMMODNAME': 'Corundum - undifferentiated'},
#  {'COMMODID': 'Dol', 'COMMODNAME': 'Dolomite'},
#  {'COMMODID': 'Fel', 'COMMODNAME': 'Feldspar'},
#  {'COMMODID': 'Grt', 'COMMODNAME': 'Garnet'},
#  {'COMMODID': 'Ge', 'COMMODNAME': 'Germanium'},
# ...

# %%
[commod['COMMODID'] for commod in db.get_commodities()]
# Out:
# ['Ag',
#  'Pb',
#  'Zn',
#  'Cu',
#  'Zr',
#  'Al',
#  'Bx',
#  'Gp',
#  'Sb',
#  'As',
#  'Ba',
#  'Be',
#  'Cd',
#  'Cs',
#  'Kln',
#  'Cor',
#  'Dol',
#  'Fel',
#  'Grt',
#  'Ge',
#  'Gr',
#  'Ir',
#  'Ky',
#  'Li',
#  'Marb',
#  'Och',
#  'Mnz',
#  'Os',
#  'Peat',
#  'Pt',
#  'Re',
#  'Ru',
#  'Sdst',
#  'Sh',
#  'Sisd',
#  'Sl',
#  'Te',
#  'Th',
#  'Ti',
#  'V',
#  'Wo',
#  'Zrn',
#  'Ilm',
#  'Mnsd',
#  'Opl',
#  'Lime',
#  'Rmet',
#  'Chrp',
#  'Hem',
#  'Cal',
#  'Hg',
#  'Nb',
#  'Phos',
#  'Bent',
#  'Aga',
#  'Jade',
#  'La',
#  'Nd',
#  'Toz',
#  'Trq',
#  'Fest',
#  'Pgvl',
#  'Mg',
#  'HM',
#  'Mag',
#  'Coal',
#  'Sto',
#  'Agg',
#  'Ap',
#  'Asbc',
#  'Cali',
#  'C',
#  'Cbl',
#  'Cmat',
#  'Dmdg',
#  'Flux',
#  'Cyf',
#  'Li2O',
#  'Perl',
#  'Prl',
#  'Qtze',
#  'Sdc',
#  'Sdf',
#  'Sif',
#  'Spl',
#  'SnO2',
#  'Trvn',
#  'Trn',
#  'UN',
#  'V2O5',
#  'Cr2O3',
#  'FeOre',
#  'Ta2O5',
#  'Aggc',
#  'Aggd',
#  'Aggf',
#  'Aggm',
#  'Atta',
#  'Bor',
#  'Brck',
# ...
