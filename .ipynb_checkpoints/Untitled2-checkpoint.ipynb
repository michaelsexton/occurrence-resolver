# %%
import yaml
import cx_Oracle
import dedupe
import pandas as pd

# %%
with open("/home/michael/Developer/database.yml", 'r') as file:
    credentials = yaml.load(file)

oraprod = credentials['test']

connection = cx_Oracle.connect(user=oraprod["user"],password=oraprod["password"],dsn=oraprod["dsn"])

# %%
sql = ''' select minlocno, otherid, name, project, class, dlong, dlat, uri, commodnames
            from mgd.occurrences o
            join mgd.occurrence_concat_commods occ on occ.idno = o.minlocno
            where state = \'QLD\' and dlong is not null and dlat is not null
            '''

# %%
sql
# Out:
# " select minlocno, otherid, name, project, class, dlong, dlat, uri, commodnames\n            from mgd.occurrences o\n            join mgd.occurrence_concat_commods occ on occ.idno = o.minlocno\n            where state = 'QLD' and dlong is not null and dlat is not null\n            "

# %%
df = pd.read_sql(sql, connection, index_col=['MINLOCNO'])

# %%
settings_file = 'qld_minloc_settings.json'
training_file = 'qld_minloc_training.json'

# %%
temp_d = df.to_dict('index')

# %%
for key in temp_d:
    temp_d[key]['COORDS'] = (float(temp_d[key]['DLAT']),float(temp_d[key]['DLONG']))
    del(temp_d[key]['DLAT'])
    del(temp_d[key]['DLONG'])

# %%
temp_d
# Out:
# {222628: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.385386999999998, 145.371959),
#   'NAME': 'Queen',
#   'OTHERID': '36683',
#   'PROJECT': None,
#   'URI': None},
#  222629: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Copper, Silver, Tin',
#   'COORDS': (-17.371525, 145.37857400000001),
#   'NAME': 'Queen Of Kentucky',
#   'OTHERID': '36684',
#   'PROJECT': None,
#   'URI': None},
#  222630: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Tungsten',
#   'COORDS': (-17.353161999999998, 145.25811199999998),
#   'NAME': 'Queen Of The Mountain',
#   'OTHERID': '36685',
#   'PROJECT': None,
#   'URI': None},
#  222631: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.380897, 145.375386),
#   'NAME': 'Queen Of The South',
#   'OTHERID': '36686',
#   'PROJECT': None,
#   'URI': None},
#  222632: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.389605, 145.314138),
#   'NAME': 'Queen Of The West',
#   'OTHERID': '36687',
#   'PROJECT': None,
#   'URI': None},
#  222633: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.41299, 145.21848699999998),
#   'NAME': 'Queenslander',
#   'OTHERID': '36688',
#   'PROJECT': None,
#   'URI': None},
#  222634: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin, Lead',
#   'COORDS': (-17.439391999999998, 145.160906),
#   'NAME': 'Rainbow',
#   'OTHERID': '36689',
#   'PROJECT': None,
#   'URI': None},
#  222635: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.409346, 145.215228),
#   'NAME': 'Rajah',
#   'OTHERID': '36690',
#   'PROJECT': None,
#   'URI': None},
#  222636: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Copper, Silver, Tungsten, Lead',
#   'COORDS': (-17.362032, 145.389197),
#   'NAME': 'Rangiteer',
#   'OTHERID': '36691',
#   'PROJECT': None,
#   'URI': None},
#  222637: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.431473, 145.214072),
#   'NAME': 'Rebound',
#   'OTHERID': '36692',
#   'PROJECT': None,
#   'URI': None},
#  222638: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin, Tungsten',
#   'COORDS': (-17.447629, 145.202147),
#   'NAME': 'Red King',
#   'OTHERID': '36693',
#   'PROJECT': None,
#   'URI': None},
#  222639: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin, Copper, Silver',
#   'COORDS': (-17.376279999999998, 145.341361),
#   'NAME': 'Red Wing',
#   'OTHERID': '36694',
#   'PROJECT': None,
#   'URI': None},
#  222640: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.369018999999998, 145.252881),
#   'NAME': 'Redmont',
#   'OTHERID': '36695',
#   'PROJECT': None,
#   'URI': None},
#  222641: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.429336, 145.22774099999998),
#   'NAME': 'Referendum',
#   'OTHERID': '36696',
#   'PROJECT': None,
#   'URI': None},
#  222642: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.367411, 145.254966),
#   'NAME': 'Reliance',
#   'OTHERID': '36697',
#   'PROJECT': None,
#   'URI': None},
#  222643: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.422197, 145.237786),
#   'NAME': 'Relief',
#   'OTHERID': '36698',
#   'PROJECT': None,
#   'URI': None},
#  222644: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.382263, 145.300748),
#   'NAME': 'Rely',
#   'OTHERID': '36699',
#   'PROJECT': None,
#   'URI': None},
#  222645: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Copper, Silver',
#   'COORDS': (-17.369163999999998, 145.377184),
#   'NAME': "Richard'S Queen",
#   'OTHERID': '36700',
#   'PROJECT': None,
#   'URI': None},
#  222646: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.456371999999998, 145.121575),
#   'NAME': 'Right Bower',
#   'OTHERID': '36701',
#   'PROJECT': None,
#   'URI': None},
#  222647: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.43545, 145.204149),
#   'NAME': 'Rio Grande',
#   'OTHERID': '36702',
#   'PROJECT': None,
#   'URI': None},
#  222648: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.423274, 145.20662199999998),
#   'NAME': 'Roaring Annie',
#   'OTHERID': '36703',
#   'PROJECT': None,
#   'URI': None},
#  222649: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.449676999999998, 145.036456),
#   'NAME': 'Robinson Tunnel',
#   'OTHERID': '36704',
#   'PROJECT': None,
#   'URI': None},
#  222650: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.382292, 145.304135),
#   'NAME': 'Rosalee ',
#   'OTHERID': '36705',
#   'PROJECT': None,
#   'URI': None},
#  222651: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.490675, 145.216319),
#   'NAME': 'Rose',
#   'OTHERID': '36706',
#   'PROJECT': None,
#   'URI': None},
#  222652: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin, Copper',
#   'COORDS': (-17.387923999999998, 145.318388),
#   'NAME': 'Rose Of England',
#   'OTHERID': '36707',
#   'PROJECT': None,
#   'URI': None},
#  222653: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin, Molybdenum, Bismuth, Copper',
#   'COORDS': (-17.464436, 145.114431),
#   'NAME': 'Rose Of Tralee',
#   'OTHERID': '36708',
#   'PROJECT': None,
#   'URI': None},
#  222654: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.428796, 145.217863),
#   'NAME': 'Rosey Rose Line',
#   'OTHERID': '36709',
#   'PROJECT': None,
#   'URI': None},
#  222655: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Copper, Silver',
#   'COORDS': (-17.371418, 145.376599),
#   'NAME': 'Royal Actor ',
#   'OTHERID': '36710',
#   'PROJECT': None,
#   'URI': None},
#  222656: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.465384, 145.025933),
#   'NAME': 'Royal Standard',
#   'OTHERID': '36711',
#   'PROJECT': None,
#   'URI': None},
#  222657: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.476191999999998, 145.02252099999998),
#   'NAME': 'Ruby',
#   'OTHERID': '36712',
#   'PROJECT': None,
#   'URI': None},
#  222658: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.387553, 145.254022),
#   'NAME': 'Ruby Ann',
#   'OTHERID': '36713',
#   'PROJECT': None,
#   'URI': None},
#  222659: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Copper, Silver',
#   'COORDS': (-17.380557, 145.37802399999998),
#   'NAME': 'Rutledge',
#   'OTHERID': '36714',
#   'PROJECT': None,
#   'URI': None},
#  222660: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.421810999999998, 145.245226),
#   'NAME': 'Sailor Boy ',
#   'OTHERID': '36715',
#   'PROJECT': None,
#   'URI': None},
#  222661: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin, Tungsten',
#   'COORDS': (-17.38786, 145.365067),
#   'NAME': 'Sandra Mary ',
#   'OTHERID': '36716',
#   'PROJECT': None,
#   'URI': None},
#  222662: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.191592, 145.116275),
#   'NAME': 'Sandy Creek',
#   'OTHERID': '36717',
#   'PROJECT': None,
#   'URI': None},
#  222663: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.481244999999998, 145.021902),
#   'NAME': 'Saurian ',
#   'OTHERID': '36718',
#   'PROJECT': None,
#   'URI': None},
#  222664: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.412969, 145.216134),
#   'NAME': 'Scab',
#   'OTHERID': '36719',
#   'PROJECT': None,
#   'URI': None},
#  222665: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.495252, 145.222866),
#   'NAME': 'Scandinavian',
#   'OTHERID': '36720',
#   'PROJECT': None,
#   'URI': None},
#  222666: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Copper, Silver, Lead',
#   'COORDS': (-17.456044, 145.285379),
#   'NAME': 'Schlumacher ',
#   'OTHERID': '36721',
#   'PROJECT': None,
#   'URI': None},
#  222667: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin, Tungsten',
#   'COORDS': (-17.382282, 145.368034),
#   'NAME': 'Scorpeus',
#   'OTHERID': '36722',
#   'PROJECT': None,
#   'URI': None},
#  222668: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.384946, 145.308063),
#   'NAME': 'Scottish Chief',
#   'OTHERID': '36723',
#   'PROJECT': None,
#   'URI': None},
#  222669: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.48707, 145.217296),
#   'NAME': 'Scratcher',
#   'OTHERID': '36724',
#   'PROJECT': None,
#   'URI': None},
#  222670: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.462533, 145.011843),
#   'NAME': 'Second Division ',
#   'OTHERID': '36725',
#   'PROJECT': None,
#   'URI': None},
#  222671: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin, Copper, Silver, Zinc, Tungsten',
#   'COORDS': (-17.375056, 145.33553799999999),
#   'NAME': 'Separation',
#   'OTHERID': '36726',
#   'PROJECT': None,
#   'URI': None},
#  222672: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Flux, Lead, Silver, Limestone',
#   'COORDS': (-17.455064, 145.276445),
#   'NAME': 'Shorts',
#   'OTHERID': '36727',
#   'PROJECT': None,
#   'URI': None},
#  222674: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Copper, Silver, Tin',
#   'COORDS': (-17.45372, 145.080372),
#   'NAME': 'Magpie',
#   'OTHERID': '36729',
#   'PROJECT': None,
#   'URI': None},
#  222675: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Copper, Tin, Lead, Zinc',
#   'COORDS': (-17.453561999999998, 145.073408),
#   'NAME': 'Morning Star',
#   'OTHERID': '36730',
#   'PROJECT': None,
#   'URI': None},
#  222676: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Copper, Lead, Silver',
#   'COORDS': (-17.453274999999998, 145.07171599999998),
#   'NAME': 'Mount Emma',
#   'OTHERID': '36731',
#   'PROJECT': None,
#   'URI': None},
#  222677: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Copper',
#   'COORDS': (-17.45396, 145.086582),
#   'NAME': 'Mount Gossan Extended',
#   'OTHERID': '36732',
#   'PROJECT': None,
#   'URI': None},
#  222678: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Copper, Silver',
#   'COORDS': (-17.454206, 145.083944),
#   'NAME': 'Mount Gossan West',
#   'OTHERID': '36733',
#   'PROJECT': None,
#   'URI': None},
#  222679: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Copper, Silver, Tin, Zinc',
#   'COORDS': (-17.454124, 145.075473),
#   'NAME': 'Mount Volk',
#   'OTHERID': '36734',
#   'PROJECT': None,
#   'URI': None},
#  222680: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Copper, Silver, Gold',
#   'COORDS': (-17.453878, 145.08742999999998),
#   'NAME': 'New Mount Gossan',
#   'OTHERID': '36735',
#   'PROJECT': None,
#   'URI': None},
#  222681: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.45616, 145.08044),
#   'NAME': 'Rainbow',
#   'OTHERID': '36736',
#   'PROJECT': None,
#   'URI': None},
#  222682: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Copper, Silver, Gold',
#   'COORDS': (-17.453902, 145.089877),
#   'NAME': 'Saint Ledger',
#   'OTHERID': '36737',
#   'PROJECT': None,
#   'URI': None},
#  222683: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.452856999999998, 145.075203),
#   'NAME': 'Unnamed 954691',
#   'OTHERID': '36738',
#   'PROJECT': None,
#   'URI': None},
#  222684: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.452354, 145.079256),
#   'NAME': 'Unnamed 959692',
#   'OTHERID': '36739',
#   'PROJECT': None,
#   'URI': None},
#  222685: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Copper',
#   'COORDS': (-17.454492, 145.085541),
#   'NAME': 'Unnamed 965689',
#   'OTHERID': '36740',
#   'PROJECT': None,
#   'URI': None},
#  222686: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Copper',
#   'COORDS': (-17.455588, 145.086753),
#   'NAME': 'Unnamed 967688',
#   'OTHERID': '36741',
#   'PROJECT': None,
#   'URI': None},
#  222687: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Antimony',
#   'COORDS': (-17.329929, 145.431626),
#   'NAME': 'Silver John',
#   'OTHERID': '36742',
#   'PROJECT': None,
#   'URI': None},
#  222688: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Antimony',
#   'COORDS': (-17.331004, 145.430394),
#   'NAME': 'Silver John Extended',
#   'OTHERID': '36743',
#   'PROJECT': None,
#   'URI': None},
#  222689: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.387524, 145.379186),
#   'NAME': 'Silver King',
#   'OTHERID': '36744',
#   'PROJECT': None,
#   'URI': None},
#  222690: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin, Silver, Lead, Zinc, Gold',
#   'COORDS': (-17.427687, 145.14577500000001),
#   'NAME': 'Silver Queen',
#   'OTHERID': '36745',
#   'PROJECT': None,
#   'URI': None},
#  222691: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Lead, Silver, Zinc',
#   'COORDS': (-17.443870999999998, 145.089699),
#   'NAME': 'Silver Star?',
#   'OTHERID': '36746',
#   'PROJECT': None,
#   'URI': None},
#  222692: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Silver, Lead',
#   'COORDS': (-17.461433, 145.281563),
#   'NAME': 'Silver Streak?',
#   'OTHERID': '36747',
#   'PROJECT': None,
#   'URI': None},
#  222693: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Lead, Silver',
#   'COORDS': (-17.464126999999998, 145.279655),
#   'NAME': 'Silver Valley',
#   'OTHERID': '36748',
#   'PROJECT': None,
#   'URI': None},
#  222694: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.42324, 145.202857),
#   'NAME': 'Skully',
#   'OTHERID': '36749',
#   'PROJECT': None,
#   'URI': None},
#  222695: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.380525, 145.374166),
#   'NAME': 'Skyscraper',
#   'OTHERID': '36750',
#   'PROJECT': None,
#   'URI': None},
#  222696: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.450571, 145.129165),
#   'NAME': 'Smalgamar',
#   'OTHERID': '36751',
#   'PROJECT': None,
#   'URI': None},
#  222697: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.400783999999998, 145.217664),
#   'NAME': 'Snapper',
#   'OTHERID': '36752',
#   'PROJECT': None,
#   'URI': None},
#  222698: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.423405, 145.221209),
#   'NAME': 'Snifter',
#   'OTHERID': '36753',
#   'PROJECT': None,
#   'URI': None},
#  222699: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.389513, 145.324585),
#   'NAME': 'Snob',
#   'OTHERID': '36754',
#   'PROJECT': None,
#   'URI': None},
#  222700: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.405677999999998, 145.209146),
#   'NAME': 'Snorter',
#   'OTHERID': '36755',
#   'PROJECT': None,
#   'URI': None},
#  222701: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.422102, 145.278637),
#   'NAME': 'Something',
#   'OTHERID': '36756',
#   'PROJECT': None,
#   'URI': None},
#  222702: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.481621, 145.023404),
#   'NAME': 'Sparklet',
#   'OTHERID': '36757',
#   'PROJECT': None,
#   'URI': None},
#  222703: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.387539999999998, 145.305028),
#   'NAME': 'Spear',
#   'OTHERID': '36758',
#   'PROJECT': None,
#   'URI': None},
#  222704: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.388157, 145.32459699999998),
#   'NAME': 'Saint George',
#   'OTHERID': '36759',
#   'PROJECT': None,
#   'URI': None},
#  222705: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.438308, 145.170706),
#   'NAME': 'Saint George?',
#   'OTHERID': '36760',
#   'PROJECT': None,
#   'URI': None},
#  222706: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.39128, 145.319863),
#   'NAME': 'Saint Kilda',
#   'OTHERID': '36761',
#   'PROJECT': None,
#   'URI': None},
#  222707: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.385171, 145.36763200000001),
#   'NAME': 'Saint Mungo',
#   'OTHERID': '36762',
#   'PROJECT': None,
#   'URI': None},
#  222708: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.439729, 145.158267),
#   'NAME': 'Saint Patrick',
#   'OTHERID': '36763',
#   'PROJECT': None,
#   'URI': None},
#  222709: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Copper, Tungsten',
#   'COORDS': (-17.379576999999998, 145.368716),
#   'NAME': 'Saint Patrick',
#   'OTHERID': '36764',
#   'PROJECT': None,
#   'URI': None},
#  222710: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin, Tungsten',
#   'COORDS': (-17.391878, 145.326445),
#   'NAME': "Saint Patrick'S Day?",
#   'OTHERID': '36765',
#   'PROJECT': None,
#   'URI': None},
#  222711: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.446474, 145.032254),
#   'NAME': 'Stallon ',
#   'OTHERID': '36766',
#   'PROJECT': None,
#   'URI': None},
#  222712: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.448149, 145.209673),
#   'NAME': 'Standard',
#   'OTHERID': '36767',
#   'PROJECT': None,
#   'URI': None},
#  222713: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Copper, Silver',
#   'COORDS': (-17.259256, 145.203983),
#   'NAME': 'Atlanta North',
#   'OTHERID': '36769',
#   'PROJECT': None,
#   'URI': None},
#  222714: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Copper, Silver, Tungsten, Tin',
#   'COORDS': (-17.260624, 145.20538),
#   'NAME': 'Atlanta',
#   'OTHERID': '36770',
#   'PROJECT': None,
#   'URI': None},
#  222715: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin, Silver, Lead, Zinc',
#   'COORDS': (-17.324437, 145.217932),
#   'NAME': 'Baalgammon',
#   'OTHERID': '36771',
#   'PROJECT': None,
#   'URI': None},
#  222716: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Copper, Tin',
#   'COORDS': (-17.29296, 145.234695),
#   'NAME': 'Barytes',
#   'OTHERID': '36772',
#   'PROJECT': None,
#   'URI': None},
#  222717: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Copper',
#   'COORDS': (-17.264778, 145.205152),
#   'NAME': 'Black Onyx',
#   'OTHERID': '36773',
#   'PROJECT': None,
#   'URI': None},
#  222718: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.304493, 145.210599),
#   'NAME': 'Black Rock',
#   'OTHERID': '36774',
#   'PROJECT': None,
#   'URI': None},
#  222719: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Copper',
#   'COORDS': (-17.263795, 145.20629),
#   'NAME': 'Blanche',
#   'OTHERID': '36775',
#   'PROJECT': None,
#   'URI': None},
#  222720: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Lead, Silver, Tin, Zinc',
#   'COORDS': (-17.328954, 145.217888),
#   'NAME': 'Bock Hill',
#   'OTHERID': '36776',
#   'PROJECT': None,
#   'URI': None},
#  222721: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin, Copper',
#   'COORDS': (-17.311197, 145.212603),
#   'NAME': 'Bowyang',
#   'OTHERID': '36777',
#   'PROJECT': None,
#   'URI': None},
#  222722: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tungsten',
#   'COORDS': (-17.296445, 145.220083),
#   'NAME': 'British',
#   'OTHERID': '36778',
#   'PROJECT': None,
#   'URI': None},
#  222723: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin, Lead',
#   'COORDS': (-17.318974, 145.213281),
#   'NAME': 'Colenso.',
#   'OTHERID': '36779',
#   'PROJECT': None,
#   'URI': None},
#  222724: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.310872, 145.216651),
#   'NAME': 'Crack In The Rock',
#   'OTHERID': '36780',
#   'PROJECT': None,
#   'URI': None},
#  222725: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin, Copper',
#   'COORDS': (-17.313074, 145.210328),
#   'NAME': 'Cudmores',
#   'OTHERID': '36781',
#   'PROJECT': None,
#   'URI': None},
#  222726: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.314275, 145.243898),
#   'NAME': 'Culwullar',
#   'OTHERID': '36782',
#   'PROJECT': None,
#   'URI': None},
#  222727: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin, Lead',
#   'COORDS': (-17.300352, 145.202174),
#   'NAME': 'Dead Finish ',
#   'OTHERID': '36783',
#   'PROJECT': None,
#   'URI': None},
#  222728: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.302609999999998, 145.202152),
#   'NAME': 'Dead Finish Extended',
#   'OTHERID': '36784',
#   'PROJECT': None,
#   'URI': None},
#  222729: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Copper, Tungsten',
#   'COORDS': (-17.277962, 145.224492),
#   'NAME': 'Eagle',
#   'OTHERID': '36785',
#   'PROJECT': None,
#   'URI': None},
#  222730: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin, Copper, Zinc',
#   'COORDS': (-17.310382, 145.212423),
#   'NAME': 'Eclipse',
#   'OTHERID': '36786',
#   'PROJECT': None,
#   'URI': None},
#  222731: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.300511, 145.220043),
#   'NAME': 'Empire',
#   'OTHERID': '36787',
#   'PROJECT': None,
#   'URI': None},
#  222732: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.327624, 145.220723),
#   'NAME': 'Eureka',
#   'OTHERID': '36788',
#   'PROJECT': None,
#   'URI': None},
#  222733: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Silver, Lead, Tin, Copper, Zinc',
#   'COORDS': (-17.327139, 145.216965),
#   'NAME': 'Evelyn 3',
#   'OTHERID': '36789',
#   'PROJECT': None,
#   'URI': None},
#  222734: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.315372999999997, 145.21472699999998),
#   'NAME': 'General White?',
#   'OTHERID': '36790',
#   'PROJECT': None,
#   'URI': None},
#  222735: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin, Tungsten, Copper',
#   'COORDS': (-17.306705, 145.225628),
#   'NAME': 'Gladstone',
#   'OTHERID': '36791',
#   'PROJECT': None,
#   'URI': None},
#  222736: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.298679, 145.217239),
#   'NAME': 'Glen Ayron',
#   'OTHERID': '36792',
#   'PROJECT': None,
#   'URI': None},
#  222737: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.295963999999998, 145.216795),
#   'NAME': 'Glengarry',
#   'OTHERID': '36793',
#   'PROJECT': None,
#   'URI': None},
#  222738: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.314038, 145.21709099999998),
#   'NAME': 'Good Friday',
#   'OTHERID': '36794',
#   'PROJECT': None,
#   'URI': None},
#  222739: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin, Copper, Lead',
#   'COORDS': (-17.320558, 145.239135),
#   'NAME': 'Great Eastern',
#   'OTHERID': '36795',
#   'PROJECT': None,
#   'URI': None},
#  222740: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Copper, Tin',
#   'COORDS': (-17.320781, 145.21326299999998),
#   'NAME': 'Great Western',
#   'OTHERID': '36796',
#   'PROJECT': None,
#   'URI': None},
#  222741: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Copper, Lead, Zinc',
#   'COORDS': (-17.318982, 145.214221),
#   'NAME': 'Great Western No.2',
#   'OTHERID': '36797',
#   'PROJECT': None,
#   'URI': None},
#  222742: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.304564, 145.218593),
#   'NAME': 'Highland Mary',
#   'OTHERID': '36798',
#   'PROJECT': None,
#   'URI': None},
#  222743: {'CLASS': 'Care And Maintenance',
#   'COMMODNAMES': 'Tin, Copper, Lead, Zinc',
#   'COORDS': (-17.316499, 145.239926),
#   'NAME': 'Home Rule',
#   'OTHERID': '36799',
#   'PROJECT': None,
#   'URI': None},
#  222744: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.314465, 145.214265),
#   'NAME': "Hornet'S Nest",
#   'OTHERID': '36800',
#   'PROJECT': None,
#   'URI': None},
#  222745: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.254898, 145.171583),
#   'NAME': 'Huntingfield',
#   'OTHERID': '36801',
#   'PROJECT': None,
#   'URI': None},
#  222746: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tungsten, Tin',
#   'COORDS': (-17.299616, 145.220993),
#   'NAME': 'Imperial',
#   'OTHERID': '36802',
#   'PROJECT': None,
#   'URI': None},
#  222747: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin, Lead',
#   'COORDS': (-17.295019, 145.212101),
#   'NAME': 'Intermediate',
#   'OTHERID': '36803',
#   'PROJECT': None,
#   'URI': None},
#  222748: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.291895, 145.216364),
#   'NAME': 'Iona',
#   'OTHERID': '36804',
#   'PROJECT': None,
#   'URI': None},
#  222749: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin, Lead, Zinc',
#   'COORDS': (-17.327616, 145.219782),
#   'NAME': 'Ironclad',
#   'OTHERID': '36805',
#   'PROJECT': None,
#   'URI': None},
#  222750: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.260122, 145.199743),
#   'NAME': 'Isolation',
#   'OTHERID': '36806',
#   'PROJECT': None,
#   'URI': None},
#  222751: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin, Zinc',
#   'COORDS': (-17.309019, 145.211496),
#   'NAME': 'Ivanhoe',
#   'OTHERID': '36807',
#   'PROJECT': None,
#   'URI': None},
#  222752: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.311096, 145.242047),
#   'NAME': 'Jimminy Cricket',
#   'OTHERID': '36808',
#   'PROJECT': None,
#   'URI': None},
#  222753: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin, Silver',
#   'COORDS': (-17.336282, 145.229107),
#   'NAME': 'Jubilee',
#   'OTHERID': '36809',
#   'PROJECT': None,
#   'URI': None},
#  222754: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin, Lead',
#   'COORDS': (-17.325708, 145.20851199999998),
#   'NAME': 'Katherine',
#   'OTHERID': '36810',
#   'PROJECT': None,
#   'URI': None},
#  222755: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.302948999999998, 145.209673),
#   'NAME': 'Kitchener Extended',
#   'OTHERID': '36811',
#   'PROJECT': None,
#   'URI': None},
#  222756: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.306292, 145.209641),
#   'NAME': 'Kitchener',
#   'OTHERID': '36812',
#   'PROJECT': None,
#   'URI': None},
#  222757: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.25191, 145.190889),
#   'NAME': 'Kookaburra',
#   'OTHERID': '36813',
#   'PROJECT': None,
#   'URI': None},
#  222758: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.295047999999998, 145.215393),
#   'NAME': "Lad O'Gowrie",
#   'OTHERID': '36814',
#   'PROJECT': None,
#   'URI': None},
#  222759: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Silver, Lead, Copper, Zinc',
#   'COORDS': (-17.297282, 145.21255),
#   'NAME': 'Lady Duff?',
#   'OTHERID': '36815',
#   'PROJECT': None,
#   'URI': None},
#  222760: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Copper, Tungsten',
#   'COORDS': (-17.266555, 145.211906),
#   'NAME': 'Lady Ena?',
#   'OTHERID': '36816',
#   'PROJECT': None,
#   'URI': None},
#  222761: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin, Copper, Fluorite',
#   'COORDS': (-17.296416, 145.216791),
#   'NAME': "Lass O'Gowrie",
#   'OTHERID': '36817',
#   'PROJECT': None,
#   'URI': None},
#  222762: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tungsten, Copper',
#   'COORDS': (-17.276543999999998, 145.21745199999998),
#   'NAME': 'Last Chance',
#   'OTHERID': '36818',
#   'PROJECT': None,
#   'URI': None},
#  222763: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.312915999999998, 145.243441),
#   'NAME': 'Leslie',
#   'OTHERID': '36819',
#   'PROJECT': None,
#   'URI': None},
#  222764: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.306258, 145.20587899999998),
#   'NAME': 'Maori',
#   'OTHERID': '36820',
#   'PROJECT': None,
#   'URI': None},
#  222765: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.309737, 145.24159),
#   'NAME': 'Mary',
#   'OTHERID': '36821',
#   'PROJECT': None,
#   'URI': None},
#  222766: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.318327999999998, 145.242448),
#   'NAME': 'Mary Of Argyle',
#   'OTHERID': '36822',
#   'PROJECT': None,
#   'URI': None},
#  222767: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.308743, 145.210934),
#   'NAME': 'Monarch',
#   'OTHERID': '36823',
#   'PROJECT': None,
#   'URI': None},
#  222768: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.317926, 145.248096),
#   'NAME': 'New Eastern',
#   'OTHERID': '36824',
#   'PROJECT': None,
#   'URI': None},
#  222769: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Tin, Silver, Lead',
#   'COORDS': (-17.326066, 145.24896),
#   'NAME': 'Prospector',
#   'OTHERID': '36825',
#   'PROJECT': None,
#   'URI': None},
#  222770: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tungsten, Copper',
#   'COORDS': (-17.271064, 145.21092199999998),
#   'NAME': 'Riotinto.',
#   'OTHERID': '36826',
#   'PROJECT': None,
#   'URI': None},
#  222771: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Copper, Silver',
#   'COORDS': (-17.267476, 145.213778),
#   'NAME': 'Robin Hood',
#   'OTHERID': '36827',
#   'PROJECT': None,
#   'URI': None},
#  222772: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin, Lead',
#   'COORDS': (-17.32716, 145.219316),
#   'NAME': 'Ronald Valley',
#   'OTHERID': '36828',
#   'PROJECT': None,
#   'URI': None},
#  222773: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.293241, 145.215411),
#   'NAME': 'Rose Of England',
#   'OTHERID': '36829',
#   'PROJECT': None,
#   'URI': None},
#  222774: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.2923, 145.211187),
#   'NAME': 'Sasanof?',
#   'OTHERID': '36830',
#   'PROJECT': None,
#   'URI': None},
#  222775: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin, Copper, Lead',
#   'COORDS': (-17.305493, 145.221406),
#   'NAME': 'Shasta ',
#   'OTHERID': '36831',
#   'PROJECT': None,
#   'URI': None},
#  222776: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Copper, Silver',
#   'COORDS': (-17.338503, 145.224852),
#   'NAME': 'Silver Belle',
#   'OTHERID': '36832',
#   'PROJECT': None,
#   'URI': None},
#  222777: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin, Lead, Silver, Zinc',
#   'COORDS': (-17.333036, 145.21973),
#   'NAME': 'Silver Lining',
#   'OTHERID': '36833',
#   'PROJECT': None,
#   'URI': None},
#  222778: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.295496, 145.214919),
#   'NAME': 'Stannary Rainbow',
#   'OTHERID': '36834',
#   'PROJECT': None,
#   'URI': None},
#  222779: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.317823999999998, 145.216114),
#   'NAME': 'Telegraph',
#   'OTHERID': '36835',
#   'PROJECT': None,
#   'URI': None},
#  222780: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.310311, 145.204428),
#   'NAME': 'The Bend',
#   'OTHERID': '36836',
#   'PROJECT': None,
#   'URI': None},
#  222781: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin, Lead',
#   'COORDS': (-17.323971999999998, 145.216525),
#   'NAME': 'Thea',
#   'OTHERID': '36837',
#   'PROJECT': None,
#   'URI': None},
#  222782: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tungsten, Tin',
#   'COORDS': (-17.278401, 145.223077),
#   'NAME': 'Tungsten Hill',
#   'OTHERID': '36838',
#   'PROJECT': None,
#   'URI': None},
#  222783: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.293672, 145.213055),
#   'NAME': 'Victoria',
#   'OTHERID': '36839',
#   'PROJECT': None,
#   'URI': None},
#  222784: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Copper, Tin',
#   'COORDS': (-17.293643, 145.209763),
#   'NAME': 'Victory',
#   'OTHERID': '36840',
#   'PROJECT': None,
#   'URI': None},
#  222785: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.314503, 145.218498),
#   'NAME': 'William',
#   'OTHERID': '36841',
#   'PROJECT': None,
#   'URI': None},
#  222786: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.311177999999998, 145.21044),
#   'NAME': 'Yam',
#   'OTHERID': '36842',
#   'PROJECT': None,
#   'URI': None},
#  222787: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin, Copper',
#   'COORDS': (-17.300143, 145.209979),
#   'NAME': 'You & Me',
#   'OTHERID': '36843',
#   'PROJECT': None,
#   'URI': None},
#  222788: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.325353, 145.219334),
#   'NAME': 'Young Australian.',
#   'OTHERID': '36844',
#   'PROJECT': None,
#   'URI': None},
#  222789: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.312146, 145.238086),
#   'NAME': 'Zimmerian',
#   'OTHERID': '36845',
#   'PROJECT': None,
#   'URI': None},
#  222790: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.257178, 145.173912),
#   'NAME': 'Unnamed 057909',
#   'OTHERID': '36846',
#   'PROJECT': None,
#   'URI': None},
#  222791: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.258554999999998, 145.17624899999998),
#   'NAME': 'Unnamed 060907',
#   'OTHERID': '36847',
#   'PROJECT': None,
#   'URI': None},
#  222792: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.272196, 145.185989),
#   'NAME': 'Unnamed 070892',
#   'OTHERID': '36848',
#   'PROJECT': None,
#   'URI': None},
#  222793: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Tungsten',
#   'COORDS': (-17.263626, 145.18748399999998),
#   'NAME': 'Unnamed 072902',
#   'OTHERID': '36849',
#   'PROJECT': None,
#   'URI': None},
#  222794: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.252681, 145.19624199999998),
#   'NAME': 'Unnamed 081914',
#   'OTHERID': '36850',
#   'PROJECT': None,
#   'URI': None},
#  222795: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Copper, Lead',
#   'COORDS': (-17.319751, 145.199163),
#   'NAME': 'Unnamed 085840',
#   'OTHERID': '36851',
#   'PROJECT': None,
#   'URI': None},
#  222796: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tungsten, Tin',
#   'COORDS': (-17.256249, 145.201191),
#   'NAME': 'Unnamed 086910',
#   'OTHERID': '36852',
#   'PROJECT': None,
#   'URI': None},
#  222797: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.308926, 145.20114999999998),
#   'NAME': 'Unnamed 087852',
#   'OTHERID': '36853',
#   'PROJECT': None,
#   'URI': None},
#  222798: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.296281999999998, 145.201743),
#   'NAME': 'Unnamed 087866',
#   'OTHERID': '36854',
#   'PROJECT': None,
#   'URI': None},
#  222799: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.258701, 145.202578),
#   'NAME': 'Unnamed 088907',
#   'OTHERID': '36855',
#   'PROJECT': None,
#   'URI': None},
#  222800: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Tungsten',
#   'COORDS': (-17.263778, 145.204409),
#   'NAME': 'Unnamed 090902',
#   'OTHERID': '36856',
#   'PROJECT': None,
#   'URI': None},
#  222801: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.295323, 145.205703),
#   'NAME': 'Unnamed 091867',
#   'OTHERID': '36857',
#   'PROJECT': None,
#   'URI': None},
#  222802: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tungsten',
#   'COORDS': (-17.266517999999998, 145.207674),
#   'NAME': 'Unnamed 093899',
#   'OTHERID': '36858',
#   'PROJECT': None,
#   'URI': None},
#  222803: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.296349, 145.209267),
#   'NAME': 'Unnamed 095866',
#   'OTHERID': '36859',
#   'PROJECT': None,
#   'URI': None},
#  222804: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.311366, 145.211285),
#   'NAME': 'Unnamed 097849',
#   'OTHERID': '36860',
#   'PROJECT': None,
#   'URI': None},
#  222805: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.318254, 145.213664),
#   'NAME': 'Unnamed 100841',
#   'OTHERID': '36861',
#   'PROJECT': None,
#   'URI': None},
#  222806: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.30858, 145.212911),
#   'NAME': 'Unnamed 099852',
#   'OTHERID': '36862',
#   'PROJECT': None,
#   'URI': None},
#  222807: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.290066, 145.213936),
#   'NAME': 'Unnamed 100873',
#   'OTHERID': '36863',
#   'PROJECT': None,
#   'URI': None},
#  222808: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.2878, 145.213206),
#   'NAME': 'Unnamed 099875',
#   'OTHERID': '36864',
#   'PROJECT': None,
#   'URI': None},
#  222809: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.316271999999998, 145.214248),
#   'NAME': 'Unnamed 101844',
#   'OTHERID': '36865',
#   'PROJECT': None,
#   'URI': None},
#  222810: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.309943, 145.213838),
#   'NAME': 'Unnamed 100851',
#   'OTHERID': '36866',
#   'PROJECT': None,
#   'URI': None},
#  222811: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.327122, 145.215083),
#   'NAME': 'Unnamed 102832',
#   'OTHERID': '36867',
#   'PROJECT': None,
#   'URI': None},
#  222812: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Silver, Lead, Tin, Zinc',
#   'COORDS': (-17.328034, 145.216015),
#   'NAME': 'Unnamed 103831',
#   'OTHERID': '36868',
#   'PROJECT': None,
#   'URI': None},
#  222813: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Silver, Lead, Tin, Zinc',
#   'COORDS': (-17.326679, 145.216029),
#   'NAME': 'Unnamed 103832',
#   'OTHERID': '36869',
#   'PROJECT': None,
#   'URI': None},
#  222814: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tungsten',
#   'COORDS': (-17.279242, 145.216016),
#   'NAME': 'Unnamed 102885',
#   'OTHERID': '36870',
#   'PROJECT': None,
#   'URI': None},
#  222815: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.318552999999998, 145.216765),
#   'NAME': 'Unnamed 103841',
#   'OTHERID': '36871',
#   'PROJECT': None,
#   'URI': None},
#  222816: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.316751999999997, 145.217441),
#   'NAME': 'Unnamed 104843',
#   'OTHERID': '36872',
#   'PROJECT': None,
#   'URI': None},
#  222817: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin, Copper',
#   'COORDS': (-17.303648, 145.217191),
#   'NAME': 'Unnamed 104858',
#   'OTHERID': '36873',
#   'PROJECT': None,
#   'URI': None},
#  222818: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.269316, 145.217522),
#   'NAME': 'Unnamed 104896',
#   'OTHERID': '36874',
#   'PROJECT': None,
#   'URI': None},
#  222819: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Tin, Copper',
#   'COORDS': (-17.311788, 145.218054),
#   'NAME': 'Unnamed 105849',
#   'OTHERID': '36875',
#   'PROJECT': None,
#   'URI': None},
#  222820: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.299591, 145.21817099999998),
#   'NAME': 'Unnamed 105862',
#   'OTHERID': '36876',
#   'PROJECT': None,
#   'URI': None},
#  222821: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Tungsten',
#   'COORDS': (-17.301406, 145.21909399999998),
#   'NAME': 'Unnamed 106860',
#   'OTHERID': '36877',
#   'PROJECT': None,
#   'URI': None},
#  222822: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.291650999999998, 145.21947),
#   'NAME': 'Unnamed 106871',
#   'OTHERID': '36878',
#   'PROJECT': None,
#   'URI': None},
#  222823: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tungsten',
#   'COORDS': (-17.283337, 145.219268),
#   'NAME': 'Unnamed 106880',
#   'OTHERID': '36879',
#   'PROJECT': None,
#   'URI': None},
#  222824: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin, Lead',
#   'COORDS': (-17.317673, 145.219408),
#   'NAME': 'Unnamed 106842',
#   'OTHERID': '36880',
#   'PROJECT': None,
#   'URI': None},
#  222825: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tungsten, Copper',
#   'COORDS': (-17.2847, 145.220195),
#   'NAME': 'Unnamed 107879',
#   'OTHERID': '36881',
#   'PROJECT': None,
#   'URI': None},
#  222826: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tungsten',
#   'COORDS': (-17.300971, 145.22098),
#   'NAME': 'Unnamed 108861',
#   'OTHERID': '36882',
#   'PROJECT': None,
#   'URI': None},
#  222827: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Tungsten',
#   'COORDS': (-17.274774, 145.221702),
#   'NAME': 'Unnamed 108890',
#   'OTHERID': '36883',
#   'PROJECT': None,
#   'URI': None},
#  222828: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin, Copper',
#   'COORDS': (-17.308215999999998, 145.222791),
#   'NAME': 'Unnamed 110853',
#   'OTHERID': '36884',
#   'PROJECT': None,
#   'URI': None},
#  222829: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin, Tungsten, Fluorite',
#   'COORDS': (-17.306413, 145.223279),
#   'NAME': 'Unnamed 110855',
#   'OTHERID': '36885',
#   'PROJECT': None,
#   'URI': None},
#  222830: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Copper',
#   'COORDS': (-17.305149999999998, 145.223479),
#   'NAME': 'Unnamed 110856',
#   'OTHERID': '36886',
#   'PROJECT': None,
#   'URI': None},
#  222831: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin, Tungsten',
#   'COORDS': (-17.304429, 145.223768),
#   'NAME': 'Unnamed 111857',
#   'OTHERID': '36887',
#   'PROJECT': None,
#   'URI': None},
#  222832: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin, Copper',
#   'COORDS': (-17.32314, 145.224529),
#   'NAME': 'Unnamed 112836',
#   'OTHERID': '36888',
#   'PROJECT': None,
#   'URI': None},
#  222833: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin, Copper',
#   'COORDS': (-17.321329, 145.224076),
#   'NAME': 'Unnamed 111838',
#   'OTHERID': '36889',
#   'PROJECT': None,
#   'URI': None},
#  222834: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.320429, 145.224555),
#   'NAME': 'Unnamed 112839',
#   'OTHERID': '36890',
#   'PROJECT': None,
#   'URI': None},
#  222835: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin, Copper',
#   'COORDS': (-17.309587999999998, 145.224659),
#   'NAME': 'Unnamed 112851',
#   'OTHERID': '36891',
#   'PROJECT': None,
#   'URI': None},
#  222836: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Copper',
#   'COORDS': (-17.306062, 145.224411),
#   'NAME': 'Unnamed 111855',
#   'OTHERID': '36892',
#   'PROJECT': None,
#   'URI': None},
#  222837: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tungsten',
#   'COORDS': (-17.305611, 145.224509),
#   'NAME': 'Unnamed 111855',
#   'OTHERID': '36893',
#   'PROJECT': None,
#   'URI': None},
#  222838: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Copper',
#   'COORDS': (-17.341665, 145.224821),
#   'NAME': 'Unnamed 112816',
#   'OTHERID': '36894',
#   'PROJECT': None,
#   'URI': None},
#  222839: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Tungsten',
#   'COORDS': (-17.299218, 145.22710999999998),
#   'NAME': 'Unnamed 114863',
#   'OTHERID': '36895',
#   'PROJECT': None,
#   'URI': None},
#  222840: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Silver, Lead, Zinc',
#   'COORDS': (-17.348019, 145.228053),
#   'NAME': 'Unnamed 116809',
#   'OTHERID': '36896',
#   'PROJECT': None,
#   'URI': None},
#  222841: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.335404, 145.231937),
#   'NAME': 'Unnamed 120823',
#   'OTHERID': '36897',
#   'PROJECT': None,
#   'URI': None},
#  222842: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Tungsten',
#   'COORDS': (-17.298361, 145.232292),
#   'NAME': 'Unnamed 120864',
#   'OTHERID': '36898',
#   'PROJECT': None,
#   'URI': None},
#  222843: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tungsten',
#   'COORDS': (-17.294316, 145.234682),
#   'NAME': 'Unnamed 122868',
#   'OTHERID': '36899',
#   'PROJECT': None,
#   'URI': None},
#  222844: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.31241, 145.23733099999998),
#   'NAME': 'Unnamed 125848',
#   'OTHERID': '36900',
#   'PROJECT': None,
#   'URI': None},
#  222845: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.315317, 145.239091),
#   'NAME': 'Unnamed 127845',
#   'OTHERID': '36901',
#   'PROJECT': None,
#   'URI': None},
#  222846: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.314045999999998, 145.23835),
#   'NAME': 'Unnamed 126846',
#   'OTHERID': '36902',
#   'PROJECT': None,
#   'URI': None},
#  222847: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.304299, 145.23976),
#   'NAME': 'Unnamed 128857',
#   'OTHERID': '36903',
#   'PROJECT': None,
#   'URI': None},
#  222848: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Tin, Lead, Silver',
#   'COORDS': (-17.338644, 145.24075),
#   'NAME': 'Unnamed 129819',
#   'OTHERID': '36904',
#   'PROJECT': None,
#   'URI': None},
#  222849: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.315634, 145.24435499999998),
#   'NAME': 'Unnamed 133845',
#   'OTHERID': '36905',
#   'PROJECT': None,
#   'URI': None},
#  222850: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin, Lead, Silver, Copper',
#   'COORDS': (-17.317453999999998, 145.245749),
#   'NAME': 'Unnamed 134843',
#   'OTHERID': '36906',
#   'PROJECT': None,
#   'URI': None},
#  222851: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.316558, 145.24669799999998),
#   'NAME': 'Unnamed 135844',
#   'OTHERID': '36907',
#   'PROJECT': None,
#   'URI': None},
#  222852: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin, Tungsten, Rutile',
#   'COORDS': (-17.314750999999998, 145.246716),
#   'NAME': 'Unnamed 135846',
#   'OTHERID': '36908',
#   'PROJECT': None,
#   'URI': None},
#  222853: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.303027, 145.249178),
#   'NAME': 'Unnamed 138859',
#   'OTHERID': '36909',
#   'PROJECT': None,
#   'URI': None},
#  222854: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Fluorite',
#   'COORDS': (-17.316131, 145.249525),
#   'NAME': 'Unnamed 138844',
#   'OTHERID': '36910',
#   'PROJECT': None,
#   'URI': None},
#  222855: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin, Tungsten',
#   'COORDS': (-17.387235999999998, 145.366013),
#   'NAME': 'Stannum ',
#   'OTHERID': '36911',
#   'PROJECT': None,
#   'URI': None},
#  222856: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin, Copper, Silver',
#   'COORDS': (-17.428884, 145.227745),
#   'NAME': 'Stannum Ace',
#   'OTHERID': '36912',
#   'PROJECT': None,
#   'URI': None},
#  222857: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.389453, 145.213539),
#   'NAME': 'Star Of The South',
#   'OTHERID': '36913',
#   'PROJECT': None,
#   'URI': None},
#  222858: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.469746, 145.010353),
#   'NAME': 'Starlight',
#   'OTHERID': '36914',
#   'PROJECT': None,
#   'URI': None},
#  222859: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin, Copper, Silver, Tungsten, Zinc',
#   'COORDS': (-17.424183, 145.342906),
#   'NAME': 'Stella',
#   'OTHERID': '36915',
#   'PROJECT': None,
#   'URI': None},
#  222860: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.422466, 145.342827),
#   'NAME': 'Stella Extended',
#   'OTHERID': '36916',
#   'PROJECT': None,
#   'URI': None},
#  222861: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin, Molybdenum',
#   'COORDS': (-17.408262999999998, 145.298061),
#   'NAME': 'Steve Mac',
#   'OTHERID': '36917',
#   'PROJECT': None,
#   'URI': None},
#  222862: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin, Tungsten, Copper',
#   'COORDS': (-17.388078999999998, 145.315281),
#   'NAME': 'Stewarts T. Claim ',
#   'OTHERID': '36918',
#   'PROJECT': None,
#   'URI': None},
#  222863: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin, Tungsten',
#   'COORDS': (-17.367672, 145.25374),
#   'NAME': 'Stromboli',
#   'OTHERID': '36919',
#   'PROJECT': None,
#   'URI': None},
#  222864: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.374845999999998, 145.22704199999998),
#   'NAME': 'Struskz Welcome',
#   'OTHERID': '36920',
#   'PROJECT': None,
#   'URI': None},
#  222865: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.431328999999998, 145.198072),
#   'NAME': 'Submarine',
#   'OTHERID': '36921',
#   'PROJECT': None,
#   'URI': None},
#  222866: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.419314, 145.218425),
#   'NAME': 'Sugar Bag',
#   'OTHERID': '36922',
#   'PROJECT': None,
#   'URI': None},
#  222867: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.450934999999998, 145.026559),
#   'NAME': 'Sugar Bag',
#   'OTHERID': '36923',
#   'PROJECT': None,
#   'URI': None},
#  222868: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin, Copper, Tungsten, Zinc',
#   'COORDS': (-17.390109, 145.32025),
#   'NAME': 'Sullivan',
#   'OTHERID': '36924',
#   'PROJECT': None,
#   'URI': None},
#  222869: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin, Copper, Silver',
#   'COORDS': (-17.370425, 145.248257),
#   'NAME': 'Sulphide',
#   'OTHERID': '36925',
#   'PROJECT': None,
#   'URI': None},
#  222870: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.459794, 145.00895500000001),
#   'NAME': 'Sultan?',
#   'OTHERID': '36926',
#   'PROJECT': None,
#   'URI': None},
#  222871: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.384242, 145.216789),
#   'NAME': 'Sunbeam',
#   'OTHERID': '36927',
#   'PROJECT': None,
#   'URI': None},
#  222872: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.444577, 145.059948),
#   'NAME': 'Sunburst',
#   'OTHERID': '36928',
#   'PROJECT': None,
#   'URI': None},
#  222873: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.441889, 145.118711),
#   'NAME': 'Sunrise',
#   'OTHERID': '36929',
#   'PROJECT': None,
#   'URI': None},
#  222874: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.43902, 145.15978),
#   'NAME': 'Sunset',
#   'OTHERID': '36930',
#   'PROJECT': None,
#   'URI': None},
#  222875: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin, Lead, Silver, Zinc',
#   'COORDS': (-17.327576, 145.26682),
#   'NAME': 'Sunset',
#   'OTHERID': '36931',
#   'PROJECT': None,
#   'URI': None},
#  222876: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.417376, 145.203856),
#   'NAME': 'Sunshine',
#   'OTHERID': '36932',
#   'PROJECT': None,
#   'URI': None},
#  222877: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin, Copper, Silver',
#   'COORDS': (-17.439819999999997, 145.035526),
#   'NAME': 'Sunshine',
#   'OTHERID': '36933',
#   'PROJECT': None,
#   'URI': None},
#  222878: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.382706, 145.375653),
#   'NAME': 'Surprise',
#   'OTHERID': '36934',
#   'PROJECT': None,
#   'URI': None},
#  222879: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.443725999999998, 145.028519),
#   'NAME': 'Surprise',
#   'OTHERID': '36935',
#   'PROJECT': None,
#   'URI': None},
#  222880: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.445429999999998, 145.208758),
#   'NAME': 'Surprise',
#   'OTHERID': '36936',
#   'PROJECT': None,
#   'URI': None},
#  222881: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tungsten',
# ...
#   'NAME': 'Unnamed 881667',
#   'OTHERID': '37603',
#   'PROJECT': None,
#   'URI': None},
#  223548: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Tungsten',
#   'COORDS': (-17.457603, 145.00672),
#   'NAME': 'Unnamed 882685',
#   'OTHERID': '37604',
#   'PROJECT': None,
#   'URI': None},
#  223549: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tungsten',
#   'COORDS': (-17.165281999999998, 145.010809),
#   'NAME': 'Unnamed 883009',
#   'OTHERID': '37605',
#   'PROJECT': None,
#   'URI': None},
#  223550: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Unspecified/Unknown',
#   'COORDS': (-17.474774, 145.007192),
#   'NAME': 'Unnamed 882666',
#   'OTHERID': '37606',
#   'PROJECT': None,
#   'URI': None},
#  223551: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.459781, 145.007637),
#   'NAME': 'Unnamed 883683',
#   'OTHERID': '37607',
#   'PROJECT': None,
#   'URI': None},
#  223552: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.457974, 145.007657),
#   'NAME': 'Unnamed 883685',
#   'OTHERID': '37608',
#   'PROJECT': None,
#   'URI': None},
#  223553: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.464306999999998, 145.008529),
#   'NAME': 'Unnamed 884678',
#   'OTHERID': '37609',
#   'PROJECT': None,
#   'URI': None},
#  223554: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.456719, 145.008612),
#   'NAME': 'Unnamed 884686',
#   'OTHERID': '37610',
#   'PROJECT': None,
#   'URI': None},
#  223555: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tungsten, Tin',
#   'COORDS': (-17.445337, 145.00883),
#   'NAME': 'Unnamed 884699',
#   'OTHERID': '37611',
#   'PROJECT': None,
#   'URI': None},
#  223556: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tungsten',
#   'COORDS': (-17.443983, 145.008938),
#   'NAME': 'Unnamed 884700',
#   'OTHERID': '37612',
#   'PROJECT': None,
#   'URI': None},
#  223557: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Tungsten',
#   'COORDS': (-17.443168, 145.008759),
#   'NAME': 'Unnamed 884701',
#   'OTHERID': '37613',
#   'PROJECT': None,
#   'URI': None},
#  223558: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.441723, 145.008775),
#   'NAME': 'Unnamed 884703',
#   'OTHERID': '37614',
#   'PROJECT': None,
#   'URI': None},
#  223559: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin, Tungsten',
#   'COORDS': (-17.464316, 145.00947),
#   'NAME': 'Unnamed 885678',
#   'OTHERID': '37615',
#   'PROJECT': None,
#   'URI': None},
#  223560: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.458896, 145.009529),
#   'NAME': 'Unnamed 885684',
#   'OTHERID': '37616',
#   'PROJECT': None,
#   'URI': None},
#  223561: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Copper',
#   'COORDS': (-17.212276, 145.01218699999998),
#   'NAME': 'Unnamed 885957',
#   'OTHERID': '37617',
#   'PROJECT': None,
#   'URI': None},
#  223562: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Copper',
#   'COORDS': (-17.468846, 145.010739),
#   'NAME': 'Unnamed 886673',
#   'OTHERID': '37618',
#   'PROJECT': None,
#   'URI': None},
#  223563: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tungsten',
#   'COORDS': (-17.449783999999998, 145.010758),
#   'NAME': 'Unnamed 886694',
#   'OTHERID': '37619',
#   'PROJECT': None,
#   'URI': None},
#  223564: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin, Tungsten, Molybdenum',
#   'COORDS': (-17.458012, 145.01142199999998),
#   'NAME': 'Unnamed 887685',
#   'OTHERID': '37620',
#   'PROJECT': None,
#   'URI': None},
#  223565: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Unspecified/Unknown',
#   'COORDS': (-17.461268999999998, 145.011951),
#   'NAME': 'Unnamed 887681',
#   'OTHERID': '37621',
#   'PROJECT': None,
#   'URI': None},
#  223566: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.445373999999997, 145.01250000000002),
#   'NAME': 'Unnamed 888699',
#   'OTHERID': '37622',
#   'PROJECT': None,
#   'URI': None},
#  223567: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Antimony, Gold',
#   'COORDS': (-17.051514, 145.018122),
#   'NAME': 'Unnamed 889135',
#   'OTHERID': '37623',
#   'PROJECT': None,
#   'URI': None},
#  223568: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Unspecified/Unknown',
#   'COORDS': (-17.471946, 145.01353),
#   'NAME': 'Unnamed 889669',
#   'OTHERID': '37624',
#   'PROJECT': None,
#   'URI': None},
#  223569: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Unspecified/Unknown',
#   'COORDS': (-17.449001, 145.013778),
#   'NAME': 'Unnamed 889695',
#   'OTHERID': '37625',
#   'PROJECT': None,
#   'URI': None},
#  223570: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tungsten, Copper',
#   'COORDS': (-17.497069, 145.014198),
#   'NAME': 'Unnamed 890641',
#   'OTHERID': '37626',
#   'PROJECT': None,
#   'URI': None},
#  223571: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.456232999999997, 145.014265),
#   'NAME': 'Unnamed 890687',
#   'OTHERID': '37627',
#   'PROJECT': None,
#   'URI': None},
#  223572: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Unspecified/Unknown',
#   'COORDS': (-17.447746, 145.014827),
#   'NAME': 'Unnamed 890696',
#   'OTHERID': '37628',
#   'PROJECT': None,
#   'URI': None},
#  223573: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tungsten, Tin',
#   'COORDS': (-17.498338999999998, 145.014749),
#   'NAME': 'Unnamed 891640',
#   'OTHERID': '37629',
#   'PROJECT': None,
#   'URI': None},
#  223574: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Copper',
#   'COORDS': (-17.474221, 145.015199),
#   'NAME': 'Unnamed 891667',
#   'OTHERID': '37630',
#   'PROJECT': None,
#   'URI': None},
#  223575: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.488773, 145.015795),
#   'NAME': 'Unnamed 892651',
#   'OTHERID': '37631',
#   'PROJECT': None,
#   'URI': None},
#  223576: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Unspecified/Unknown',
#   'COORDS': (-17.442884, 145.01648),
#   'NAME': 'Unnamed 892701',
#   'OTHERID': '37632',
#   'PROJECT': None,
#   'URI': None},
#  223577: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Copper',
#   'COORDS': (-17.445242, 145.017396),
#   'NAME': 'Unnamed 893699',
#   'OTHERID': '37633',
#   'PROJECT': None,
#   'URI': None},
#  223578: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Copper',
#   'COORDS': (-17.426178999999998, 145.017414),
#   'NAME': 'Unnamed 893720',
#   'OTHERID': '37634',
#   'PROJECT': None,
#   'URI': None},
#  223579: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Copper',
#   'COORDS': (-17.176215, 145.020091),
#   'NAME': 'Unnamed 893997',
#   'OTHERID': '37635',
#   'PROJECT': None,
#   'URI': None},
#  223580: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Fluorite',
#   'COORDS': (-17.154989999999998, 145.020786),
#   'NAME': 'Unnamed 893020',
#   'OTHERID': '37636',
#   'PROJECT': None,
#   'URI': None},
#  223581: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Copper',
#   'COORDS': (-17.448596, 145.018489),
#   'NAME': 'Unnamed 894695',
#   'OTHERID': '37637',
#   'PROJECT': None,
#   'URI': None},
#  223582: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Copper',
#   'COORDS': (-17.186161, 145.020925),
#   'NAME': 'Unnamed 894986',
#   'OTHERID': '37638',
#   'PROJECT': None,
#   'URI': None},
#  223583: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Unspecified/Unknown',
#   'COORDS': (-17.437859, 145.019923),
#   'NAME': 'Unnamed 895707',
#   'OTHERID': '37639',
#   'PROJECT': None,
#   'URI': None},
#  223584: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tungsten',
#   'COORDS': (-17.482135, 145.020574),
#   'NAME': 'Unnamed 897658',
#   'OTHERID': '37640',
#   'PROJECT': None,
#   'URI': None},
#  223585: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Tungsten, Lead, Zinc, Gold, Silver',
#   'COORDS': (-17.107602999999997, 145.02551599999998),
#   'NAME': 'Unnamed 898073',
#   'OTHERID': '37641',
#   'PROJECT': None,
#   'URI': None},
#  223586: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Molybdenum',
#   'COORDS': (-17.102634, 145.025568),
#   'NAME': 'Unnamed 898078',
#   'OTHERID': '37642',
#   'PROJECT': None,
#   'URI': None},
#  223587: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Antimony, Silver, Gold',
#   'COORDS': (-17.052505, 145.027035),
#   'NAME': 'Unnamed 899134',
#   'OTHERID': '37643',
#   'PROJECT': None,
#   'URI': None},
#  223588: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Unspecified/Unknown',
#   'COORDS': (-17.447098, 145.02236399999998),
#   'NAME': 'Unnamed 898697',
#   'OTHERID': '37644',
#   'PROJECT': None,
#   'URI': None},
#  223589: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.483428, 145.023384),
#   'NAME': 'Unnamed 900657',
#   'OTHERID': '37645',
#   'PROJECT': None,
#   'URI': None},
#  223590: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Unspecified/Unknown',
#   'COORDS': (-17.454967, 145.023221),
#   'NAME': 'Unnamed 899688',
#   'OTHERID': '37646',
#   'PROJECT': None,
#   'URI': None},
#  223591: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.484341, 145.024316),
#   'NAME': 'Unnamed 901656',
#   'OTHERID': '37647',
#   'PROJECT': None,
#   'URI': None},
#  223592: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.452541999999998, 145.02465899999999),
#   'NAME': 'Unnamed 901691',
#   'OTHERID': '37648',
#   'PROJECT': None,
#   'URI': None},
#  223593: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Copper, Lead',
#   'COORDS': (-17.428331999999997, 145.02492),
#   'NAME': 'Unnamed 901718',
#   'OTHERID': '37649',
#   'PROJECT': None,
#   'URI': None},
#  223594: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.48435, 145.025257),
#   'NAME': 'Unnamed 902656',
#   'OTHERID': '37650',
#   'PROJECT': None,
#   'URI': None},
#  223595: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.481282, 145.025667),
#   'NAME': 'Unnamed 902659',
#   'OTHERID': '37651',
#   'PROJECT': None,
#   'URI': None},
#  223596: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Unspecified/Unknown',
#   'COORDS': (-17.470799, 145.02540299999998),
#   'NAME': 'Unnamed 902671',
#   'OTHERID': '37652',
#   'PROJECT': None,
#   'URI': None},
#  223597: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.447854, 145.02565099999998),
#   'NAME': 'Unnamed 902696',
#   'OTHERID': '37653',
#   'PROJECT': None,
#   'URI': None},
#  223598: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.442615999999997, 145.025895),
#   'NAME': 'Unnamed 902702',
#   'OTHERID': '37654',
#   'PROJECT': None,
#   'URI': None},
#  223599: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.483456, 145.026208),
#   'NAME': 'Unnamed 903657',
#   'OTHERID': '37655',
#   'PROJECT': None,
#   'URI': None},
#  223600: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Unspecified/Unknown',
#   'COORDS': (-17.470176, 145.026352),
#   'NAME': 'Unnamed 903671',
#   'OTHERID': '37656',
#   'PROJECT': None,
#   'URI': None},
#  223601: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.443251999999998, 145.026265),
#   'NAME': 'Unnamed 902701',
#   'OTHERID': '37657',
#   'PROJECT': None,
#   'URI': None},
#  223602: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Unspecified/Unknown',
#   'COORDS': (-17.497018, 145.027286),
#   'NAME': 'Unnamed 904642',
#   'OTHERID': '37658',
#   'PROJECT': None,
#   'URI': None},
#  223603: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.450036, 145.027039),
#   'NAME': 'Unnamed 903694',
#   'OTHERID': '37659',
#   'PROJECT': None,
#   'URI': None},
#  223604: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Gold, Antimony',
#   'COORDS': (-17.092309, 145.032253),
#   'NAME': 'Unnamed 905090',
#   'OTHERID': '37660',
#   'PROJECT': None,
#   'URI': None},
#  223605: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Unspecified/Unknown',
#   'COORDS': (-17.474268, 145.028943),
#   'NAME': 'Unnamed 905667',
#   'OTHERID': '37661',
#   'PROJECT': None,
#   'URI': None},
#  223606: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.456561999999998, 145.029134),
#   'NAME': 'Unnamed 905686',
#   'OTHERID': '37662',
#   'PROJECT': None,
#   'URI': None},
#  223607: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.441926, 145.029197),
#   'NAME': 'Unnamed 905703',
#   'OTHERID': '37663',
#   'PROJECT': None,
#   'URI': None},
#  223608: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.447, 145.03064899999998),
#   'NAME': 'Unnamed 907697',
#   'OTHERID': '37664',
#   'PROJECT': None,
#   'URI': None},
#  223609: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Fluorite',
#   'COORDS': (-17.103177, 145.034957),
#   'NAME': 'Unnamed 908078',
#   'OTHERID': '37665',
#   'PROJECT': None,
#   'URI': None},
#  223610: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.446464, 145.031313),
#   'NAME': 'Unnamed 908698',
#   'OTHERID': '37666',
#   'PROJECT': None,
#   'URI': None},
#  223611: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.451902999999998, 145.033137),
#   'NAME': 'Unnamed 910692',
#   'OTHERID': '37667',
#   'PROJECT': None,
#   'URI': None},
#  223612: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.448836, 145.033547),
#   'NAME': 'Unnamed 910695',
#   'OTHERID': '37668',
#   'PROJECT': None,
#   'URI': None},
#  223613: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.441063, 145.033254),
#   'NAME': 'Unnamed 910704',
#   'OTHERID': '37669',
#   'PROJECT': None,
#   'URI': None},
#  223614: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.440521, 145.03325999999998),
#   'NAME': 'Unnamed 910704',
#   'OTHERID': '37670',
#   'PROJECT': None,
#   'URI': None},
#  223615: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.431126, 145.03336),
#   'NAME': 'Unnamed 910715',
#   'OTHERID': '37671',
#   'PROJECT': None,
#   'URI': None},
#  223616: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.449925, 145.0341),
#   'NAME': 'Unnamed 911694',
#   'OTHERID': '37672',
#   'PROJECT': None,
#   'URI': None},
#  223617: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.445228, 145.03415),
#   'NAME': 'Unnamed 911699',
#   'OTHERID': '37673',
#   'PROJECT': None,
#   'URI': None},
#  223618: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.444686, 145.034156),
#   'NAME': 'Unnamed 911700',
#   'OTHERID': '37674',
#   'PROJECT': None,
#   'URI': None},
#  223619: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.439086, 145.03431),
#   'NAME': 'Unnamed 911706',
#   'OTHERID': '37675',
#   'PROJECT': None,
#   'URI': None},
#  223620: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.438361999999998, 145.034224),
#   'NAME': 'Unnamed 911707',
#   'OTHERID': '37676',
#   'PROJECT': None,
#   'URI': None},
#  223621: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.437279999999998, 145.034424),
#   'NAME': 'Unnamed 911708',
#   'OTHERID': '37677',
#   'PROJECT': None,
#   'URI': None},
#  223622: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.440904, 145.035514),
#   'NAME': 'Unnamed 912704',
#   'OTHERID': '37678',
#   'PROJECT': None,
#   'URI': None},
#  223623: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.439089, 145.034687),
#   'NAME': 'Unnamed 911706',
#   'OTHERID': '37679',
#   'PROJECT': None,
#   'URI': None},
#  223624: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.449225, 145.036366),
#   'NAME': 'Unnamed 913695',
#   'OTHERID': '37680',
#   'PROJECT': None,
#   'URI': None},
#  223625: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.446966, 145.03639099999998),
#   'NAME': 'Unnamed 913697',
#   'OTHERID': '37681',
#   'PROJECT': None,
#   'URI': None},
#  223626: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.446512, 145.036113),
#   'NAME': 'Unnamed 913698',
#   'OTHERID': '37682',
#   'PROJECT': None,
#   'URI': None},
#  223627: {'CLASS': 'Abandoned Mine',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.442897, 145.036058),
#   'NAME': 'Unnamed 913702',
#   'OTHERID': '37683',
#   'PROJECT': None,
#   'URI': None},
#  223628: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Tin',
#   'COORDS': (-17.442021999999998, 145.038891),
#   'NAME': 'Unnamed 916703',
#   'OTHERID': '37684',
#   'PROJECT': None,
#   'URI': None},
#  223629: {'CLASS': 'Mineral Occurrence',
#   'COMMODNAMES': 'Fluorite',
#   'COORDS': (-17.105978, 145.044323),
#   'NAME': 'Unnamed 918075',
#   'OTHERID': '37685',
#   'PROJECT': None,
#   'URI': None},
#  ...}

# %%
fields = [
    {
        'field' : 'OTHERID',
        'variable name' : 'otherid',
        'type' : 'String'
    },{
        'field' : 'NAME',
        'variable name' : 'name',
        'type' : 'String',
        'has missing' : True
    },{
        'field' : 'CLASS',
        'variable name' : 'class',
        'type' : 'String',
        'has missing' : True
    },{
        'field' : 'COORDS',
        'variable name' : 'coordinates',
        'type' : 'LatLong',
    },{
        'field' : 'COMMODNAMES',
        'variable name' : 'commodities',
        'type' : 'String',
    }, {
        'field' : 'PROJECT',
        'variable name' : 'project',
        'type' : 'String',
        'has missing' : True
    }
]

# %%
deduper = dedupe.Dedupe(fields)

# %%
deduper.sample(temp_d, 50)
# Out:
# INFO:dedupe.canopy_index:Removing stop word 37
# INFO:dedupe.canopy_index:Removing stop word 78
# INFO:dedupe.canopy_index:Removing stop word Q5
# INFO:dedupe.canopy_index:Removing stop word 42
# INFO:dedupe.canopy_index:Removing stop word Q4
# INFO:dedupe.canopy_index:Removing stop word 32
# INFO:dedupe.canopy_index:Removing stop word 07
# INFO:dedupe.canopy_index:Removing stop word 50
# INFO:dedupe.canopy_index:Removing stop word 39
# INFO:dedupe.canopy_index:Removing stop word 45
# INFO:dedupe.canopy_index:Removing stop word 41
# INFO:dedupe.canopy_index:Removing stop word 54
# INFO:dedupe.canopy_index:Removing stop word 06
# INFO:dedupe.canopy_index:Removing stop word 43
# INFO:dedupe.canopy_index:Removing stop word 40
# INFO:dedupe.canopy_index:Removing stop word 48
# INFO:dedupe.canopy_index:Removing stop word Q3
# INFO:dedupe.canopy_index:Removing stop word 47
# INFO:dedupe.canopy_index:Removing stop word 38
# INFO:dedupe.canopy_index:Removing stop word 36
# INFO:dedupe.canopy_index:Removing stop word AM
# INFO:dedupe.canopy_index:Removing stop word ED
# INFO:dedupe.canopy_index:Removing stop word NA
# INFO:dedupe.canopy_index:Removing stop word UN
# INFO:dedupe.canopy_index:Removing stop word AN
# INFO:dedupe.canopy_index:Removing stop word OR
# INFO:dedupe.canopy_index:Removing stop word Un
# INFO:dedupe.canopy_index:Removing stop word d
# INFO:dedupe.canopy_index:Removing stop word me
# INFO:dedupe.canopy_index:Removing stop word nn
# INFO:dedupe.canopy_index:Removing stop word ER
# INFO:dedupe.canopy_index:Removing stop word LA
# INFO:dedupe.canopy_index:Removing stop word  2
# INFO:dedupe.canopy_index:Removing stop word  C
# INFO:dedupe.canopy_index:Removing stop word LE
# INFO:dedupe.canopy_index:Removing stop word AR
# INFO:dedupe.canopy_index:Removing stop word RO
# INFO:dedupe.canopy_index:Removing stop word  P
# INFO:dedupe.canopy_index:Removing stop word S
# INFO:dedupe.canopy_index:Removing stop word  1
# INFO:dedupe.canopy_index:Removing stop word E
# INFO:dedupe.canopy_index:Removing stop word IN
# INFO:dedupe.canopy_index:Removing stop word EE
# INFO:dedupe.canopy_index:Removing stop word RE
# INFO:dedupe.canopy_index:Removing stop word ON
# INFO:dedupe.canopy_index:Removing stop word UNNAMED
# INFO:dedupe.canopy_index:Removing stop word Unnamed

# %%
dedupe.convenience.consoleLabel(deduper)
# Out:
# OTHERID : Q479461
# NAME : UNNAMED 421009
# CLASS : ABANDONED MINE
# COORDS : (-18.074344, 142.34409399999998)
# COMMODNAMES : Gold
# PROJECT : None
#
# OTHERID : Q479461
# NAME : UNNAMED 421009
# CLASS : ABANDONED MINE
# COORDS : (-18.074344, 142.34409399999998)
# COMMODNAMES : Gold
# PROJECT : None
#
# 0/10 positive, 0/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished

# %%
deduper.train()

# %%
clustered_dupes = deduper.match(temp_d, 0.2)

# %%
len(clustered_dupes)

# %%
cluster_membership = {}
cluster_id = 0

# %%
for cluster_id, (cluster, scores) in enumerate(clustered_dupes):
    for record_id, score in zip(cluster, scores):
        cluster_membership[record_id] = (cluster_id, score)

# %%
cluster_membership

# %%
clustered_dupes[-100]
